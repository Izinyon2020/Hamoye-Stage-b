# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Multiple Linear Regression

# %%
#import relevant data

df = pd.read_csv('energydata_complete.csv')
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00        60.0    30.0  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00        60.0    30.0  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00        50.0    30.0  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00        50.0    40.0  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00        60.0    40.0  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4     ...        RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000     ...       45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000     ...       45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667     ...       45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000     ...       45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000     ...       45.40  6.133333        733.9
#
# ...

# %%
#This is an overview of the correlation between variables
df.corr()
# Out:
#              Appliances    lights        T1      RH_1        T2      RH_2  \
# Appliances     1.000000  0.197278  0.055447  0.086031  0.120073 -0.060465
# lights         0.197278  1.000000 -0.023528  0.106968 -0.005622  0.050985
# T1             0.055447 -0.023528  1.000000  0.164006  0.836834 -0.002509
# RH_1           0.086031  0.106968  0.164006  1.000000  0.269839  0.797535
# T2             0.120073 -0.005622  0.836834  0.269839  1.000000 -0.165610
# RH_2          -0.060465  0.050985 -0.002509  0.797535 -0.165610  1.000000
# T3             0.085060 -0.097393  0.892402  0.253230  0.735245  0.137319
# RH_3           0.036292  0.131161 -0.028550  0.844677  0.121497  0.678326
# T4             0.040281 -0.008859  0.877001  0.106180  0.762066 -0.047304
# RH_4           0.016965  0.114936  0.097861  0.880359  0.231563  0.721435
# T5             0.019760 -0.078745  0.885247  0.205797  0.720550  0.110409
# RH_5           0.006955  0.141233 -0.014782  0.303258  0.029595  0.250271
# ...

# %%
#a small sample space (500 rows) of two highly correlated variables to plot
simple_linear_reg_df = df[['T1' , 'T3' ]].sample( 500, random_state=20)
df.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2', 'Unnamed: 29'],
#       dtype='object')

# %%
sns.pairplot(simple_linear_reg_df)

# %% [markdown]
# # Simple Linear regression Problem
#
# ## (T2 as input, T6 as output)

# %%
#we have to normalize dataset and remove irrelevant columns for future purposes

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

df = df.drop(['date', 'lights', 'Unnamed: 29'], axis=1)
normalised_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
#split normalized data into training and test sets based on required variables
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(normalised_df['T2'], normalised_df['T6'], test_size= 0.3 , random_state= 42)

# %%
#we have to reshape training and test data for ease of use and fit linear regression on test after learning with training

x_train, y_train, x_test, y_test = x_train.reshape(13814,1), y_train.reshape(13814,1), x_test.reshape(5921,1), y_test.reshape(5921,1)
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
predicted_values = linear_model.predict(x_test)
# Out:
# C:\Users\owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## Computation R$^2$ of linear model fitted

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_values)
round(r2_score, 2)
# Out:
# 0.64000000000000001

# %% [markdown]
# # (Overall data in use)
# ## Mean Absolute Error

# %%
features_df = normalised_df.drop(['Appliances'], axis=1)
target = normalised_df['Appliances']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features_df, target, test_size= 0.3 , random_state= 42)

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
predicted_values = linear_model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, predicted_values)
round(mae, 2)
# Out:
# 0.050000000000000003

# %% [markdown]
# ## Residual Sum of Squares

# %%
features_df.head()
# Out:
#         T1      RH_1        T2      RH_2        T3      RH_3        T4  \
# 0  0.32735  0.566187  0.225345  0.684038  0.215188  0.746066  0.351351
# 1  0.32735  0.541326  0.225345  0.682140  0.215188  0.748871  0.351351
# 2  0.32735  0.530502  0.225345  0.679445  0.215188  0.755569  0.344745
# 3  0.32735  0.524080  0.225345  0.678414  0.215188  0.758685  0.341441
# 4  0.32735  0.531419  0.225345  0.676727  0.215188  0.758685  0.341441
#
#        RH_4        T5      RH_5    ...           T9      RH_9     T_out  \
# 0  0.764262  0.175506  0.381691    ...     0.223032  0.677290  0.372990
# 1  0.782437  0.175506  0.381691    ...     0.226500  0.678532  0.369239
# 2  0.778062  0.175506  0.380037    ...     0.219563  0.676049  0.365488
# 3  0.770949  0.175506  0.380037    ...     0.219563  0.671909  0.361736
# 4  0.762697  0.178691  0.380037    ...     0.219563  0.671909  0.357985
#
#    Press_mm_hg    RH_out  Windspeed  Visibility  Tdewpoint       rv1       rv2
# ...

# %%
rss = np.sum(np.square(y_test - predicted_values))
round(rss, 2)
# Out:
# 45.35

# %% [markdown]
# ## Root Mean Square Error (RMSE)

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
round(rmse, 3)
# Out:
# 0.087999999999999995

# %% [markdown]
# ## Coefficient of Determination (R$^2$)

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_values)
r2_score
# Out:
# 0.14890246319303535

# %%
#define a function that returns the weight of every feature

def get_weights_df(model, feat, col_name):
    '''Return the weights of model alongside their
        respective columns in feat, under col_name
        as column header'''
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = [ 'Features' , col_name]
    weights_df[col_name].round( 3 )
    return weights_df

# %%
#return the weights learned with linear model
linear_model_weights = get_weights_df(linear_model, x_train, 'Linear_Model_Weight' )
linear_model_weights
# Out:
#        Features  Linear_Model_Weight
# 0          RH_2            -0.456698
# 1         T_out            -0.321860
# 2            T2            -0.236178
# 3            T9            -0.189941
# 4          RH_8            -0.157595
# 5        RH_out            -0.077671
# 6          RH_7            -0.044614
# 7          RH_9            -0.039800
# 8            T5            -0.015657
# 9            T1            -0.003281
# 10          rv1             0.000770
# 11          rv2             0.000770
# 12  Press_mm_hg             0.006839
# 13           T7             0.010319
# 14   Visibility             0.012307
# 15         RH_5             0.016006
# 16         RH_4             0.026386
# 17           T4             0.028981
# 18    Windspeed             0.029183
# 19         RH_6             0.038049
# 20         RH_3             0.096048
# 21           T8             0.101995
# 22    Tdewpoint             0.117758
# 23           T6             0.236425
# ...

# %% [markdown]
# # Penalization Methods

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha= 0.4)
ridge_reg.fit(x_train, y_train)

ridge_predicted_values = ridge_reg.predict(x_test)

# %% [markdown]
# ## RMSE of Ridge Regression

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, ridge_predicted_values))
round(rmse, 3)
# Out:
# 0.087999999999999995

# %% [markdown]
# This RMSE value is the same as that obtained using the linear regression model earlier fitted.

# %% [markdown]
# ## Feature Selection and Lasso Regression

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha= 0.001 )
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
# return lasso weights using get_weights_df function

lasso_weights_df = get_weights_df(lasso_reg, x_train, 'Lasso_weight' )
lasso_weights_df
# Out:
#        Features  Lasso_weight
# 0        RH_out     -0.049557
# 1          RH_8     -0.000110
# 2            T1      0.000000
# 3     Tdewpoint      0.000000
# 4    Visibility      0.000000
# 5   Press_mm_hg     -0.000000
# 6         T_out      0.000000
# 7          RH_9     -0.000000
# 8            T9     -0.000000
# 9            T8      0.000000
# 10         RH_7     -0.000000
# 11          rv1     -0.000000
# 12           T7     -0.000000
# 13           T6      0.000000
# 14         RH_5      0.000000
# 15           T5     -0.000000
# 16         RH_4      0.000000
# 17           T4     -0.000000
# 18         RH_3      0.000000
# 19           T3      0.000000
# 20         RH_2     -0.000000
# 21           T2      0.000000
# 22         RH_6     -0.000000
# 23          rv2     -0.000000
# 24    Windspeed      0.002912
# 25         RH_1      0.017880

# %% [markdown]
# ## RMSE of Lasso Regression

# %%
lasso_predicted_values = lasso_reg.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test, lasso_predicted_values))
round(rmse, 3)
# Out:
# 0.094
